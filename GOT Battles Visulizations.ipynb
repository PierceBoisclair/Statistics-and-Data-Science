# %% [markdown]
# Choose one variable and plot that variable four different ways.
#
# Choose two continuous variables, and plot them three different ways.
#
# Choose one continuous variable and one categorical variable, and plot them six different ways.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline



battles = pd.read_csv('battles.csv')

# %%
battles.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark        NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1 ...  major_death  major_capture  \
# 0        NaN        NaN      Tully ...          1.0            0.0
# ...

# %%
sns.set(style="whitegrid")

sns.relplot(x="attacker_size", y="defender_size", hue="region", data=battles)

# %%
sns.set(style="darkgrid")

sns.relplot(x="attacker_size", y="defender_size", hue="region", data=battles)

# %%
sns.boxplot(x="defender_king", y="defender_size",
            data=battles)

# %%
sns.factorplot(x="attacker_size", y="defender_size", data=battles,
                   size=6, kind="bar", palette="pastel")

# %%
battles.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark        NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1 ...  major_death  major_capture  \
# 0        NaN        NaN      Tully ...          1.0            0.0
# ...

# %%
g = sns.lmplot(y='attacker_size', # Variable 1.
               x='defender_size', data=battles, # Data
               fit_reg=False, # If set to true, plots a regression line.
               scatter_kws={'alpha':0.4}) 
g.set_ylabels("Attacker Size")
g.set_xlabels("Defender Size")

# %%
g = sns.lmplot(y='attacker_size', # Variable 1.
               x='defender_size', data=battles, # Data
               fit_reg=True, # If set to true, plots a regression line.
               scatter_kws={'alpha':0.4}) 
g.set_ylabels("Attacker Size")
g.set_xlabels("Defender Size")

# %%
sns.set(style="whitegrid")

sns.relplot(x="attacker_size", y="defender_size", hue="attacker_king", data=battles)

# %%
battles.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark        NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1 ...  major_death  major_capture  \
# 0        NaN        NaN      Tully ...          1.0            0.0
# ...

# %%
sns.set(style="whitegrid")

sns.relplot(x="attacker_size", y="attacker_king", hue="defender_king", size="defender_size", sizes=(15, 200), data=battles)

# %%
battles.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark        NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1 ...  major_death  major_capture  \
# 0        NaN        NaN      Tully ...          1.0            0.0
# ...

# %%
d = battles.attacker_king
boom=d.value_counts()
boom
# Out:
# Joffrey/Tommen Baratheon    14
# Robb Stark                  10
# Balon/Euron Greyjoy          7
# Stannis Baratheon            5
# Name: attacker_king, dtype: int64

# %%
attacker = ('Joffrey/Tommen Baratheon', 'Robb Stark', 'Balon/Euron Greyjoy', 'Stannis Baratheon')
y_pos = np.arange(len(attacker))
performance = [14, 10, 7, 5]
 
plt.barh(y_pos, performance, align='center', alpha=0.5)
plt.yticks(y_pos, attacker)
plt.xlabel('# of Attacks')
plt.title('# of Times as Attacking General')
# Out:
# Text(0.5, 1.0, '# of Times as Attacking General')

# %%
labels = 'Joffrey/Tommen Baratheon', 'Robb Stark', 'Balon/Euron Greyjoy', 'Stannis Baratheon'
sizes = [14, 10, 7, 5]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)
 
plt.axis('equal')
plt.show()

# %%
y = [14, 10, 7, 5]
N = len(y)
x = 'Joffrey/Tommen Baratheon', 'Robb Stark', 'Balon/Euron Greyjoy', 'Stannis Baratheon'
width = 1/1.5
plt.bar(x, y, width, color="blue")
plt.xticks(fontsize=12, rotation= 40)
# Out:
# ([0, 1, 2, 3], <a list of 4 Text xticklabel objects>)

# %% [markdown]
# # 2. 2 Continuos Variables 3 ways (I did four)

# %%
sns.set(style="whitegrid")

sns.relplot(x="attacker_size", y="defender_size", hue="attacker_king", data=battles)

# %%
g = sns.lmplot(y='attacker_size', # Variable 1.
               x='defender_size', data=battles, # Data
               fit_reg=True, # If set to true, plots a regression line.
               scatter_kws={'alpha':0.4}) 
g.set_ylabels("Attacker Size")
g.set_xlabels("Defender Size")

# %%
sns.factorplot(x="attacker_size", y="defender_size", data=battles,
                   size=6, kind="bar", palette="pastel")

# %%
sns.relplot(x="attacker_size", y="defender_size", kind="line", data=battles)

# %% [markdown]
# # 3. Choose one continuous variable and one categorical variable, and plot them six different ways.

# %%
battles.head()
## lets choose attacker king and attacker size
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark        NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1 ...  major_death  major_capture  \
# 0        NaN        NaN      Tully ...          1.0            0.0
# ...

# %%
sns.swarmplot(x="attacker_size", y="attacker_king", data=battles,
              size=5, palette="pastel", linewidth=1)

# %%
sns.boxplot(x="attacker_size", y="attacker_king", data=battles,
            )

# %%
sns.relplot(x="attacker_size", y="attacker_king", data=battles)

# %%
sns.factorplot(x="attacker_size", y="attacker_king", data=battles, join=False)

# %%
sns.relplot(x="attacker_size", y="attacker_king", 
            col="attacker_king", col_wrap=2,
           data=battles)

# %%
sns.catplot(x="attacker_king", y="attacker_size", hue="defender_size",
            col="region", col_wrap=3, aspect=.6,
            kind="swarm", data=battles);

# %%
sns.catplot(x="attacker_size", y="attacker_king", hue="major_death",
            kind="violin", split=True, data=battles);
