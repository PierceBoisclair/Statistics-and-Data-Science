# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from sklearn import linear_model
import seaborn as sns
# %matplotlib inline

crime = pd.read_csv('CRIMENY.csv', thousands=",")

# %%
crime.head()
# Out:
#                        city  population  violent crime  murder  rape1  rape2  \
# 0             Adams Village      1861.0            0.0     0.0    NaN    0.0
# 1  Addison Town and Village      2577.0            3.0     0.0    NaN    0.0
# 2             Akron Village      2846.0            3.0     0.0    NaN    0.0
# 3                    Albany     97956.0          791.0     8.0    NaN   30.0
# 4            Albion Village      6388.0           23.0     0.0    NaN    3.0
#
#    robbery  aggravatedd assault  property crime  burglary  larceny  \
# 0      0.0                  0.0            12.0       2.0     10.0
# 1      0.0                  3.0            24.0       3.0     20.0
# 2      0.0                  3.0            16.0       1.0     15.0
# 3    227.0                526.0          4090.0     705.0   3243.0
# 4      4.0                 16.0           223.0      53.0    165.0
#
#    motor vehicle theft  arson3  unnamed3
# 0                  0.0     0.0       NaN
# ...

# %%
crime.columns = ['city', 'population', 'violent crime', 'murder', 'rape1', 'rape2', 'robbery', 'aggravatedd assault', 
                'property crime', 'burglary', 'larceny', 'motor vehicle theft', 'arson3', 'unnamed3']

# %%
data = pd.DataFrame()
data['city'] = crime['city']
data['population'] = crime['population']
data['population_sq'] = (crime['population'])**2
data['murder'] = (crime['murder'] > 0).astype(int)
data['robbery'] = (crime['robbery'] > 0).astype(int)
data = data.dropna()
data.head(10)
# Out:
#                        city  population  population_sq  murder  robbery
# 0             Adams Village      1861.0   3.463321e+06       0        0
# 1  Addison Town and Village      2577.0   6.640929e+06       0        0
# 2             Akron Village      2846.0   8.099716e+06       0        0
# 3                    Albany     97956.0   9.595378e+09       1        1
# 4            Albion Village      6388.0   4.080654e+07       0        1
# 5            Alfred Village      4089.0   1.671992e+07       0        1
# 6          Allegany Village      1781.0   3.171961e+06       0        0
# 7              Amherst Town    118296.0   1.399394e+10       1        1
# 8        Amityville Village      9519.0   9.061136e+07       0        1
# 9                 Amsterdam     18182.0   3.305851e+08       0        1

# %%
y = pd.DataFrame(['population'])
x = pd.DataFrame(['population_sq'])

plt.scatter(x, y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-3b745647a032> in <module>
#       2 x = pd.DataFrame(['population_sq'])
#       3
# ----> 4 plt.scatter(x, y)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, data, **kwargs)
#    2862         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2863         verts=verts, edgecolors=edgecolors, **({"data": data} if data
# -> 2864         is not None else {}), **kwargs)
#    2865     sci(__ret)
#    2866     return __ret
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
# ...
